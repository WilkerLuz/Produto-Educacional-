# %%
import pandas as pd
import numpy as np
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

df_cluster = pd.read_csv('conhecimentos_previos2.csv')

# %%
df_cluster
# Out:
#            ID                                              Nome:  \
# 0    aluno 01                          José Cássios Costa Torres
# 1   aluno 02                          Ycaro Yan Lourenço Santos
# 2    aluno 03                      Carlos Eduardo Lima Coutinho
# 3    aluno 04                        Roberto Guilhon Rosa Filho
# 4    aluno 05                                   Francisco Leonel
# 5    aluno 06                Pedro Victor Soares da Silva Araújo
# 6    aluno 07                  Gabriel Antonio Assunção Oliveira
# 7    aluno 08                            Gabriel Viana Da Costa
# 8    aluno 09                       Carlos Eduardo Lima Coutinho
# 9    aluno 10                       Danielly dos Santos Almeida
# 10   aluno 11                    Lara Emanuelly da Silva Santos
# 11   aluno 12                          Juan Pablo de sousa silva
# 12   aluno 13                           Jonas Davi Nogueira Sena
# 13   aluno 14                            Gabriel Viana Da Costa
# 14   aluno 15                      Antonio Wills da Silva Santos
# 15   aluno 16                        Willian Jorge Sousa Furtado
# 16   aluno 17                      Luis Felipe Assunção Pereira
# 17   aluno 18                          Loyse Kelly Cardoso Diniz
# 18   aluno 19                        Randerson Sousa de Sá Nunes
# 19   aluno 20                        Lucas Eduardo Lima Da Silva
# 20   aluno 21                   Raislan Ítalo de Sousa da Silva
# 21   aluno 22                      Guilherme Oliveira de Menezes
# 22   aluno 23                       Evelly Victory Vieira Pinto
# 23   aluno 24             Crisfieldy Aristodenes Feitoza Ribeiro
# 24   aluno 25                 Samuel Ryan da Fonseca Anunciação
# 25   aluno 26                    Saymon Italo Cordeiro de Moura
# 26   aluno 27                                 Alisson vaz silva
# 27   aluno 28                                      Gustavo Neves
# 28   aluno 29                       Durval Veloso Barbosa Filho
# 29   aluno 30                            Kevyn sousa silva maia
# 30   aluno 31                         Ávila da Conceição Araújo
# 31   aluno 32                         Isaac Levi Oliveira Chaves
# 32   aluno 33                       Neudson Gabriel C. C. Branco
# 33   aluno 34                             Gustavo Marinho Santos
# 34   aluno 35                       Victor Emanuel Cunha Morais
# 35   aluno 36                  Heráclito Thiago de Castro Santos
# 36   aluno 37                    Mickaela evely Sousa de Freitas
# 37   aluno 38                       Debriane da Silva Conceição
# 38   aluno 39              Alexandre Henrique Oliveira de Sousa
# 39   aluno 40  Hipócrates Augusto Soares Brandão Galvão de Ca...
# 40   aluno 41                       Luis Eduardo Martins Formiga
#
#                                           FEEDBACK_Q1 NOTA_Q1  \
# 0   O aluno não conseguiu elaborar a sequência da ...       N
# 1   O auno coseguiu listar os passos de maneira ló...       S
# 2   O aluno coseguiu listar os passos de maneira l...       S
# 3   O aluno coseguiu listar os passos de maneira l...       S
# 4   O aluno conseguiu elaborar parcialmente a sequ...       P
# 5   O aluno conseguiu elaborar parcialmente a sequ...       P
# 6   O auno coseguiu listar os passos de maneira ló...       S
# 7                                                 NaN     NaN
# 8                                                 NaN     NaN
# 9   O aluno conseguiu elaborar parcialmente a sequ...       P
# 10  A aluna conseguiu elaborar parcialmente a sequ...       P
# 11  O aluno conseguiu elaborar parcialmente a sequ...       P
# 12  O auno coseguiu listar os passos de maneira ló...       S
# 13  O aluno conseguiu elaborar parcialmente a sequ...       P
# 14  O aluno conseguiu elaborar parcialmente a sequ...       P
# 15  O aluno conseguiu elaborar parcialmente a sequ...       P
# 16  O aluno conseguiu elaborar parcialmente a sequ...       P
# 17  O aluno conseguiu elaborar parcialmente a sequ...       P
# 18  O auno coseguiu listar os passos de maneira ló...       S
# 19  O aluno conseguiu elaborar parcialmente a sequ...       P
# 20  O aluno conseguiu elaborar parcialmente a sequ...       P
# 21  O auno coseguiu listar os passos de maneira ló...       S
# 22  O aluno conseguiu elaborar parcialmente a sequ...       P
# 23  O aluno conseguiu elaborar parcialmente a sequ...       P
# 24  O aluno conseguiu elaborar parcialmente a sequ...       P
# 25  O aluno conseguiu elaborar parcialmente a sequ...       P
# 26  O aluno coseguiu listar os passos de maneira l...       S
# 27  O aluno conseguiu elaborar parcialmente a sequ...       P
# 28  O aluno não conseguiu elaborar a sequência da ...       N
# 29                                                NaN     NaN
# 30  O aluno não conseguiu elaborar a sequência da ...       N
# 31  O auno coseguiu listar os passos de maneira ló...       S
# 32  O auno coseguiu listar os passos de maneira ló...       S
# 33  O aluno conseguiu elaborar parcialmente a sequ...       P
# 34  O auno coseguiu listar os passos de maneira ló...       S
# 35                                                NaN     NaN
# 36                                                NaN     NaN
# 37                                                NaN     NaN
# 38                                                NaN     NaN
# 39  O aluno conseguiu elaborar parcialmente a sequ...       P
# 40                                                NaN     NaN
#
#                                           FEEDBACK_Q2 NOTA_Q2  \
# 0   O aluno conseguiu elaborar parcialmente o conc...       P
# 1   O aluno conseguiu elaborar parcialmente o conc...       P
# 2   O aluno conseguiu elaborar parcialmente o conc...       P
# 3   O aluno não conseguiu elaborar um conceito par...       N
# 4   O aluno conseguiu elaborar parcialmente o conc...       P
# 5   Apesar de reconhecer que o algoritmo é uma seq...       P
# 6   O aluno cita exemplo de algoritmo mas não um c...       P
# 7                                                 NaN     NaN
# 8                                                 NaN     NaN
# 9   O aluno conseguiu elaborar parcialmente o conc...       P
# 10  Apesar de reconhecer que o algoritmo é usado p...       P
# 11  O aluno conseguiu elaborar parcialmente o conc...       P
# 12  O aluno conseguiu elaborar parcialmente o conc...       P
# 13  O aluno conseguiu elaborar parcialmente o conc...       P
# 14  O aluno conseguiu elaborar parcialmente o conc...       P
# 15  O aluno cita que o algoritmo é uma sequencia d...       P
# 16  O aluno conseguiu elaborar parcialmente o conc...       P
# 17  O aluno não coseguiu elaborar um conceito para...       N
# 18                                                NaN     NaN
# 19  O aluno não conseguiu elaborar um conceito par...       N
# 20  Apesar de reconhecer que o algoritmo é usado p...       P
# 21  O aluno conseguiu elaborar parcialmente o conc...       P
# 22  O aluno conseguiu elaborar parcialmente o conc...       P
# 23  O aluno conseguiu elaborar parcialmente o conc...       P
# 24  O aluno conseguiu elaborar parcialmente o conc...       P
# 25  O aluno não coseguiu elaborar um conceito para...       N
# 26  O aluno cita que o algoritmo é uma sequencia d...       P
# 27  O aluno conseguiu elaborar parcialmente o conc...       P
# 28  Apesar de reconhecer a importancia das linguag...       N
# 29                                                NaN     NaN
# 30  O aluno cita que o algoritmo é um conjunto de ...       P
# 31  O aluno cita que o algoritmo é uma sequencia d...       P
# 32  O aluno conseguiu elaborar parcialmente o conc...       P
# 33                                                NaN       N
# 34  O aluno não coseguiu elaborar um conceito para...       N
# 35                                                NaN     NaN
# 36                                                NaN     NaN
# 37                                                NaN     NaN
# 38                                                NaN     NaN
# 39  O aluno conseguiu elaborar parcialmente o conc...       P
# 40                                                NaN     NaN
#
#                                           FEEDBACK_Q3 NOTA_Q3  \
# 0   O aluno conseguiu reconhecer a decomposição pr...       P
# 1   O aluno conseguiu reconhecer a decomposição pr...       P
# 2   O aluno conseguiu reconhecer a decomposição pr...       P
# 3   O aluno não coseguiu elaborar uma resposta par...       N
# 4   O aluno conseguiu reconhecer a decomposição pr...       P
# 5   O aluno não coseguiu elaborar uma resposta par...       N
# 6   O aluno conseguiu reconhecer a decomposição pr...       P
# 7                                                 NaN     NaN
# 8                                                 NaN     NaN
# 9   O aluno não coseguiu elaborar uma resposta par...       N
# 10  A aluna não coseguiu elaborar uma resposta par...       N
# 11  O aluno conseguiu reconhecer a decomposição pr...       P
# 12  O aluno conseguiu reconhecer a decomposição pr...       P
# 13  O aluno conseguiu reconhecer a decomposição pr...       P
# 14  O aluno conseguiu reconhecer a decomposição pr...       P
# 15  O aluno não coseguiu elaborar uma resposta par...       N
# 16  O aluno não coseguiu elaborar uma resposta par...       N
# 17                                                NaN       N
# 18  O aluno não coseguiu elaborar uma resposta par...       N
# 19  O aluno conseguiu reconhecer a decomposição pr...       P
# 20  O aluno não coseguiu elaborar uma resposta par...       N
# 21  O aluno conseguiu reconhecer a decomposição pr...       P
# 22  O aluno conseguiu reconhecer a decomposição pr...       P
# 23  O aluno conseguiu reconhecer a decomposição pr...       P
# 24  O aluno conseguiu reconhecer a decomposição pr...       P
# 25  O aluno não coseguiu elaborar uma resposta par...       N
# 26  O aluno conseguiu reconhecer a decomposição pr...       P
# 27  O aluno não coseguiu elaborar uma resposta par...       N
# 28  O aluno não coseguiu elaborar uma resposta par...       N
# 29                                                NaN     NaN
# 30  O aluno conseguiu reconhecer a decomposição pr...       P
# 31  O aluno conseguiu reconhecer a decomposição pr...       P
# 32  O aluno conseguiu reconhecer a decomposição pr...       P
# 33  O aluno conseguiu reconhecer a decomposição pr...       P
# 34  O aluno conseguiu reconhecer a decomposição pr...       P
# 35                                                NaN     NaN
# 36                                                NaN     NaN
# 37                                                NaN     NaN
# 38                                                NaN     NaN
# 39  O aluno conseguiu reconhecer a decomposição pr...       P
# 40                                                NaN     NaN
#
#                                           FEEDBACK_Q4 NOTA_Q4  \
# 0   O aluno conseguiu reconhecer o padrão na seque...       P
# 1   O aluno não conseguiu reconhecer o padrão disp...       N
# 2   O aluno conseguiu reconhecer o padrão na seque...       P
# 3   O aluno não conseguiu reconhecer o padrão disp...       N
# 4   O aluno conseguiu reconhecer o padrão na seque...       P
# 5   O aluno não conseguiu reconhecer o padrão disp...       N
# 6   O aluno não conseguiu reconhecer o padrão disp...       N
# 7                                                 NaN     NaN
# 8                                                 NaN     NaN
# 9   O aluno conseguiu reconhecer o padrão na seque...       P
# 10  A aluna não conseguiu reconhecer o padrão disp...       N
# 11  O aluno conseguiu reconhecer o padrão disponiv...       S
# 12  O aluno não conseguiu reconhecer o padrão disp...       N
# 13                                                NaN       N
# 14  O aluno conseguiu reconhecer o padrão na seque...       P
# 15  O aluno conseguiu reconhecer o padrão na seque...       P
# 16  O aluno conseguiu reconhecer o padrão na seque...       P
# 17                                                NaN       N
# 18  O aluno conseguiu reconhecer o padrão disponiv...       S
# 19  O aluno não conseguiu reconhecer o padrão disp...       N
# 20  O aluno conseguiu reconhecer padrões, no entan...       P
# 21  O aluno conseguiu reconhecer o padrão na seque...       P
# 22  O aluno não conseguiu reconhecer o padrão disp...       N
# 23                                                NaN       N
# 24  O aluno conseguiu reconhecer o padrão na seque...       P
# 25  O aluno não conseguiu reconhecer o padrão disp...       N
# 26  O aluno não conseguiu reconhecer o padrão disp...       N
# 27  O aluno não conseguiu reconhecer o padrão disp...       N
# 28  O aluno não conseguiu reconhecer o padrão disp...       N
# 29                                                NaN     NaN
# 30  O aluno não conseguiu reconhecer o padrão disp...       N
# 31  O aluno conseguiu reconhecer o padrão na seque...       P
# 32  O aluno não conseguiu reconhecer o padrão disp...       N
# 33                                                NaN       N
# 34  O aluno conseguiu reconhecer o padrão na seque...       P
# 35                                                NaN     NaN
# 36                                                NaN     NaN
# 37                                                NaN     NaN
# 38                                                NaN     NaN
# 39  O aluno conseguiu reconhecer o padrão na seque...       P
# 40                                                NaN     NaN
#
#                                           FEEDBACK_Q5 NOTA_Q5  \
# 0   O aluno conseguiu reconhecer o padrão disponív...       S
# 1   O aluno conseguiu reconhecer o padrão disponív...       S
# 2   O aluno conseguiu reconhecer o padrão disponív...       S
# 3   O aluno conseguiu reconhecer o padrão disponív...       S
# 4   O aluno conseguiu reconhecer o padrão disponív...       P
# 5   O aluno conseguiu reconhecer o padrão disponív...       S
# 6   O aluno conseguiu reconhecer o padrão disponív...       S
# 7                                                 NaN     NaN
# 8                                                 NaN     NaN
# 9   O aluno conseguiu reconhecer o padrão disponív...       S
# 10  A aluna conseguiu reconhecer o padrão disponív...       S
# 11  O aluno conseguiu reconhecer o padrão disponív...       S
# 12  O aluno conseguiu reconhecer o padrão disponív...       S
# 13  O aluno conseguiu reconhecer o padrão disponív...       S
# 14  O aluno conseguiu reconhecer o padrão disponív...       S
# 15  O aluno conseguiu reconhecer o padrão disponív...       S
# 16  O aluno conseguiu reconhecer o padrão disponív...       S
# 17  O aluno conseguiu reconhecer o padrão disponív...       S
# 18  O aluno conseguiu reconhecer o padrão disponív...       S
# 19  O aluno conseguiu reconhecer o padrão disponív...       S
# 20  O aluno conseguiu reconhecer o padrão disponív...       S
# 21  O aluno conseguiu reconhecer o padrão disponív...       S
# 22  O aluno conseguiu reconhecer o padrão disponív...       P
# 23  O aluno conseguiu reconhecer o padrão disponív...       S
# 24  O aluno conseguiu reconhecer o padrão disponív...       S
# 25  O aluno conseguiu acertar o resultado mas não ...       P
# 26  O aluno conseguiu reconhecer o padrão disponív...       S
# 27  A aluna não conseguiu reconhecer o padrão disp...       N
# 28  O aluno conseguiu reconhecer o padrão disponív...       S
# 29                                                NaN     NaN
# 30  O aluno conseguiu reconhecer o padrão disponív...       P
# 31  O aluno conseguiu reconhecer o padrão disponív...       S
# 32  O aluno conseguiu reconhecer o padrão disponív...       S
# 33  A aluna não conseguiu reconhecer o padrão disp...       N
# 34  A aluna não conseguiu reconhecer o padrão disp...       N
# 35                                                NaN     NaN
# 36                                                NaN     NaN
# 37                                                NaN     NaN
# 38                                                NaN     NaN
# 39  O aluno conseguiu reconhecer o padrão disponív...       S
# 40                                                NaN     NaN
#
#                                           FEEDBACK_Q6 NOTA_Q6  \
# 0   O aluno conseguiu reconhecer o padrão disponiv...       S
# 1   A aluna não conseguiu reconhecer o padrão disp...       N
# 2   O aluno conseguiu reconhecer o padrão disponiv...       S
# 3   A aluna não conseguiu reconhecer o padrão disp...       N
# 4   O aluno conseguiu reconhecer o padrão disponiv...       S
# 5   O aluno não conseguiu reconhecer o padrão disp...       N
# 6   O aluno conseguiu reconhecer o padrão disponiv...       S
# 7                                                 NaN     NaN
# 8                                                 NaN     NaN
# 9   O aluno conseguiu reconhecer o padrão disponiv...       S
# 10  A aluna não conseguiu reconhecer o padrão disp...       N
# 11  A aluna não conseguiu reconhecer o padrão disp...       N
# 12  A aluna não conseguiu reconhecer o padrão disp...       N
# 13  O aluno conseguiu reconhecer o padrão disponiv...       S
# 14  O aluno conseguiu reconhecer o padrão disponiv...       S
# 15  O aluno conseguiu reconhecer o padrão disponiv...       S
# 16  O aluno conseguiu reconhecer parcialmente um p...       P
# 17  A aluna não conseguiu reconhecer o padrão disp...       N
# 18  O aluno conseguiu reconhecer parcialmente um p...       P
# 19  A aluna não conseguiu reconhecer o padrão disp...       N
# 20  O aluno não conseguiu reconhecer o padrão disp...       N
# 21  O aluno conseguiu reconhecer o padrão disponiv...       S
# 22  O aluno conseguiu reconhecer o padrão disponiv...       S
# 23  A aluna não conseguiu reconhecer o padrão disp...       N
# 24  A aluna não conseguiu reconhecer o padrão disp...       N
# 25  A aluna não conseguiu reconhecer o padrão disp...       N
# 26  O aluno conseguiu reconhecer o padrão disponiv...       S
# 27  A aluna não conseguiu reconhecer o padrão disp...       N
# 28  A aluna não conseguiu reconhecer o padrão disp...       N
# 29                                                NaN     NaN
# 30  O aluno conseguiu reconhecer o padrão disponiv...       S
# 31  O aluno conseguiu reconhecer parcialmente um p...       P
# 32  A aluna não conseguiu reconhecer o padrão disp...       N
# 33  A aluna não conseguiu reconhecer o padrão disp...       N
# 34  A aluna não conseguiu reconhecer o padrão disp...       N
# 35                                                NaN     NaN
# 36                                                NaN     NaN
# 37                                                NaN     NaN
# 38                                                NaN     NaN
# 39  O aluno conseguiu reconhecer o padrão disponiv...       S
# 40                                                NaN     NaN
#
#                                           FEEDBACK_Q7 NOTA_Q7  \
# 0   O aluno conseguiu resolver a questão por teore...       S
# 1   A aluna não conseguiu resolver a questão sobre...       N
# 2   O aluno conseguiu resolver a questão por teore...       S
# 3   A aluna não conseguiu resolver a questão sobre...       N
# 4   O aluno conseguiu resolver a questão por teore...       S
# 5   O aluno não conseguiu resolver a questão sobre...       N
# 6   A aluna não conseguiu resolver a questão sobre...       N
# 7                                                 NaN     NaN
# 8                                                 NaN     NaN
# 9   A aluna não conseguiu resolver a questão sobre...       N
# 10  A aluna não conseguiu resolver a questão sobre...       N
# 11  O aluno conseguiu resolver a questão por teore...       S
# 12  O aluno conseguiu chegar a um resultado corret...       P
# 13  A aluna não conseguiu resolver a questão sobre...       N
# 14  O aluno conseguiu resolver a questão por teore...       S
# 15  O aluno conseguiu resolver a questão por teore...       S
# 16  O aluno conseguiu chegar a um resultado corret...       P
# 17  A aluna não conseguiu resolver a questão sobre...       N
# 18  O aluno conseguiu resolver a questão por teore...       S
# 19  O aluno conseguiu resolver a questão por teore...       S
# 20  O aluno não conseguiu resolver a questão sobre...       N
# 21  O aluno conseguiu chegar a um resultado corret...       P
# 22  O aluno conseguiu resolver a questão por teore...       S
# 23                                                NaN     NaN
# 24  A aluna não conseguiu resolver a questão sobre...       N
# 25  A aluna não conseguiu resolver a questão sobre...       N
# 26  O aluno conseguiu resolver a questão por teore...       S
# 27  O aluno conseguiu chegar a um resultado corret...       P
# 28  A aluna não conseguiu resolver a questão sobre...       N
# 29                                                NaN     NaN
# 30  A aluna não conseguiu resolver a questão sobre...       N
# 31  O aluno não conseguiu resolver a questão sobre...       N
# 32  O aluno conseguiu chegar a um resultado corret...       P
# 33  A aluna não conseguiu resolver a questão sobre...       N
# 34  A aluna não conseguiu resolver a questão sobre...       N
# 35                                                NaN     NaN
# 36                                                NaN     NaN
# 37                                                NaN     NaN
# 38                                                NaN     NaN
# 39  A aluna não conseguiu resolver a questão sobre...       N
# 40                                                NaN     NaN
#
#                                           FEEDBACK_Q8 NOTA_Q8  \
# 0   O aluno conseguiu resolver a questão por teore...       S
# 1                                                 NaN       N
# 2   O aluno conseguiu resolver a questão por teore...       S
# 3   O aluno não conseguiu resolver a questão sobre...       N
# 4   O aluno conseguiu resolver a questão por teore...       S
# 5   O aluno conseguiu resolver a questão usando o ...       P
# 6   O aluno conseguiu resolver a questão por teore...       S
# 7                                                 NaN     NaN
# 8                                                 NaN     NaN
# 9   O aluno não conseguiu resolver a questão sobre...       N
# 10  A aluna não conseguiu resolver a questão sobre...       N
# 11  O aluno conseguiu resolver a questão usando o ...       P
# 12  O aluno não conseguiu resolver a questão sobre...       N
# 13  O aluno conseguiu resolver a questão usando o ...       P
# 14                                                NaN       N
# 15  O aluno conseguiu resolver a questão por teore...       S
# 16  O aluno conseguiu resolver a questão por teore...       S
# 17                                                NaN       N
# 18                                                NaN       N
# 19  O aluno conseguiu resolver a questão usando o ...       P
# 20  O aluno não conseguiu resolver a questão sobre...       N
# 21  O aluno conseguiu resolver a questão por teore...       S
# 22  O aluno conseguiu resolver a questão por teore...       S
# 23                                                NaN     NaN
# 24  O aluno não conseguiu resolver a questão sobre...       N
# 25  O aluno conseguiu resolver a questão por teore...       S
# 26  O aluno conseguiu resolver a questão por teore...       S
# 27  O aluno não conseguiu resolver a questão sobre...       N
# 28  O aluno não conseguiu resolver a questão sobre...       N
# 29                                                NaN     NaN
# 30  O aluno não conseguiu resolver a questão sobre...       N
# 31  O aluno não conseguiu resolver a questão sobre...       N
# 32  O aluno conseguiu resolver a questão por teore...       S
# 33  O aluno não conseguiu resolver a questão sobre...       N
# 34  O aluno não conseguiu resolver a questão sobre...       N
# 35                                                NaN     NaN
# 36                                                NaN     NaN
# 37                                                NaN     NaN
# 38                                                NaN     NaN
# 39  O aluno conseguiu resolver a questão por teore...       S
# 40                                                NaN     NaN
#
#                                           FEEDBACK_Q9 NOTA_Q9
# 0   O aluno conseguiu estabelecer uma relação entr...       S
# 1                                                 NaN       N
# 2   O aluno conseguiu estabelecer uma relação entr...       S
# 3   A aluna não conseguiu estabelecer uma relação ...       N
# 4   O aluno conseguiu estabelecer uma relação entr...       S
# 5   O aluno não conseguiu estabelecer uma relação ...       N
# 6   A aluna não conseguiu estabelecer uma relação ...       N
# 7                                                 NaN     NaN
# 8                                                 NaN     NaN
# 9                                                 NaN       N
# 10  A aluna não conseguiu estabelecer uma relação ...       N
# 11  O aluno conseguiu estabelecer parcialmente a r...       P
# 12  A aluna não conseguiu estabelecer uma relação ...       N
# 13  O aluno conseguiu estabelecer uma relação entr...       S
# 14                                                NaN       N
# 15  A aluna conseguiu estabelecer uma relação entr...       S
# 16  O aluno conseguiu estabelecer parcialmente a r...       P
# 17                                                NaN       N
# 18  O aluno conseguiu estabelecer parcialmente a r...       P
# 19  O aluno conseguiu estabelecer parcialmente a r...       P
# 20  O aluno não conseguiu estabelecer uma relação ...       N
# 21  O aluno conseguiu estabelecer uma relação entr...       S
# 22  O aluno conseguiu estabelecer uma relação entr...       S
# 23  A aluna não conseguiu estabelecer uma relação ...       N
# 24  A aluna não conseguiu estabelecer uma relação ...       N
# 25  A aluna não conseguiu estabelecer uma relação ...       N
# 26  A aluna conseguiu estabelecer uma relação entr...       S
# 27                                                NaN       N
# 28  A aluna não conseguiu estabelecer uma relação ...       N
# 29                                                NaN     NaN
# 30  A aluna não conseguiu estabelecer uma relação ...       N
# 31  O aluno não conseguiu estabelecer uma relação ...       N
# 32                                                NaN       N
# 33  A aluna não conseguiu estabelecer uma relação ...       N
# 34  A aluna não conseguiu estabelecer uma relação ...       N
# 35                                                NaN     NaN
# 36                                                NaN     NaN
# 37                                                NaN     NaN
# 38                                                NaN     NaN
# 39  O aluno conseguiu estabelecer parcialmente a r...       P
# 40                                                NaN     NaN

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
data_scaled = scaler.fit_transform(df_cluster)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 4
#       1 from sklearn.preprocessing import StandardScaler
#       3 scaler = StandardScaler()
# ----> 4 data_scaled = scaler.fit_transform(df_cluster)
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/utils/_set_output.py:140, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     138 @wraps(f)
#     139 def wrapped(self, X, *args, **kwargs):
# --> 140     data_to_wrap = f(self, X, *args, **kwargs)
#     141     if isinstance(data_to_wrap, tuple):
#     142         # only wrap the first output for cross decomposition
#     143         return_tuple = (
#     144             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     145             *data_to_wrap[1:],
#     146         )
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/base.py:915, in TransformerMixin.fit_transform(self, X, y, **fit_params)
#     911 # non-optimized default implementation; override when a better
#     912 # method is possible for a given clustering algorithm
#     913 if y is None:
#     914     # fit method of arity 1 (unsupervised transformation)
# --> 915     return self.fit(X, **fit_params).transform(X)
#     916 else:
#     917     # fit method of arity 2 (supervised transformation)
#     918     return self.fit(X, y, **fit_params).transform(X)
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_data.py:837, in StandardScaler.fit(self, X, y, sample_weight)
#     835 # Reset internal state before fitting
#     836 self._reset()
# --> 837 return self.partial_fit(X, y, sample_weight)
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/base.py:1151, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1144     estimator._validate_params()
#    1146 with config_context(
#    1147     skip_parameter_validation=(
#    1148         prefer_skip_nested_validation or global_skip_validation
#    1149     )
#    1150 ):
# -> 1151     return fit_method(estimator, *args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_data.py:873, in StandardScaler.partial_fit(self, X, y, sample_weight)
#     841 """Online computation of mean and std on X for later scaling.
#     842
#     843 All of X is processed as a single batch. This is intended for cases
#    (...)
#     870     Fitted scaler.
#     871 """
#     872 first_call = not hasattr(self, "n_samples_seen_")
# --> 873 X = self._validate_data(
#     874     X,
#     875     accept_sparse=("csr", "csc"),
#     876     dtype=FLOAT_DTYPES,
#     877     force_all_finite="allow-nan",
#     878     reset=first_call,
#     879 )
#     880 n_features = X.shape[1]
#     882 if sample_weight is not None:
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/base.py:604, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     602         out = X, y
#     603 elif not no_val_X and no_val_y:
# --> 604     out = check_array(X, input_name="X", **check_params)
#     605 elif no_val_X and not no_val_y:
#     606     out = _check_y(y, **check_params)
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:917, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     915         array = xp.astype(array, dtype, copy=False)
#     916     else:
# --> 917         array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#     918 except ComplexWarning as complex_warning:
#     919     raise ValueError(
#     920         "Complex data not supported\n{}\n".format(array)
#     921     ) from complex_warning
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/utils/_array_api.py:380, in _asarray_with_order(array, dtype, order, copy, xp)
#     378     array = numpy.array(array, order=order, dtype=dtype)
#     379 else:
# --> 380     array = numpy.asarray(array, order=order, dtype=dtype)
#     382 # At this point array is a NumPy ndarray. We convert it to an array
#     383 # container that is consistent with the input's namespace.
#     384 return xp.asarray(array)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/generic.py:2070, in NDFrame.__array__(self, dtype)
#    2069 def __array__(self, dtype: npt.DTypeLike | None = None) -> np.ndarray:
# -> 2070     return np.asarray(self._values, dtype=dtype)
#
# ValueError: could not convert string to float: 'aluno 01'
