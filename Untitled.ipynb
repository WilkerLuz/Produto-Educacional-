# %%
# Importando matplotlib, pandas e numpy
import pandas as pd
import matplotlib.pyplot as plt


df_moodle = pd.read_csv('logs_moodle.csv')

# %%
df_moodle.head()
# Out:
#    1          \core\event\user_loggedin  core loggedin           user  \
# 0  2  \core\event\user_password_updated  core  updated  user_password
# 1  3           \core\event\user_updated  core  updated           user
# 2  4     \core\event\config_log_created  core  created     config_log
# 3  5     \core\event\config_log_created  core  created     config_log
# 4  6     \core\event\config_log_created  core  created     config_log
#
#        user.1      2  r  0  1.1  ...  0.1  2.1  0.2  NULL  0.3  \
# 0         NaN    NaN  u  0    5  ...    2    2    0   2.0    0
# 1        user    2.0  u  0    5  ...    2    2    0   2.0    0
# 2  config_log  618.0  c  0    1  ...    0    2    0   NaN    0
# 3  config_log  619.0  c  0    1  ...    0    2    0   NaN    0
# 4  config_log  620.0  c  0    1  ...    0    2    0   NaN    0
#
#                    a:1:{s:8:"username";s:5:"admin";}  1613519797  web  \
# 0                   a:1:{s:14:"forgottenreset";b:0;}  1613519968  web
# ...
